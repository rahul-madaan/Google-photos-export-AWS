# %%
import glob
import os
from pathlib import Path
import shutil

# %%
# folder_path = '/Users/rahul.madan/Downloads/Takeout/Google Photos/Nov 2021/'
folder_path = '/Users/rahul.madan/Downloads/Takeout 2/Google Photos/May21-Sep21/'
total = glob.glob(folder_path + '*')
json = glob.glob(folder_path + '*.json')
mp3 = glob.glob(folder_path + '*.mp4')
jpg = glob.glob(folder_path + '*.jpg')
JPG = glob.glob(folder_path + '*.JPG')
jpeg = glob.glob(folder_path + '*.jpeg')
HEIC = glob.glob(folder_path + '*.HEIC')
mov = glob.glob(folder_path + '*.mov')

all_files = []
all_media = []
all_metadata = []

all_media.extend([video[len(folder_path):] for video in mp3])
all_media.extend([image[len(folder_path):] for image in jpg])
all_media.extend([image[len(folder_path):] for image in JPG])
all_media.extend([image[len(folder_path):] for image in jpeg])
all_media.extend([image[len(folder_path):] for image in HEIC])
all_media.extend([image[len(folder_path):] for image in mov])

all_metadata.extend([metadata[len(folder_path):] for metadata in json])
all_metadata.remove("metadata.json")

all_files.extend([files[len(folder_path):] for files in total])

print(all_files)
print("Total files: ", len(all_files))
print("Total metadata files: ", len(all_metadata))
print("Total media files: ", len(all_media))
# Out:
# ['IMG_20210607_162426.jpg.json', 'IMG-20210603-WA0035.jpg.json', 'VID_20210720_125519.mp4', 'IMG-20210603-WA0034.jpg.json', 'IMG_20210720_154850.jpg', 'VID_20210720_131508.mp4.json', 'IMG_20210824_001052.jpg.json', 'IMG_20210528_000037_294.png.json', 'IMG_20210720_133149.jpg', 'IMG-20210616-WA0009.jpg.json', 'IMG_20210925_202622.jpg', 'IMG_20210720_133101.jpg.json', 'IMG_20210720_133454.jpg.json', 'IMG_20210720_133632.jpg.json', 'IMG_20210720_132914.jpg', 'IMG-20210827-WA0021.jpeg.json', 'IMG_20210720_132253.jpg.json', 'VID_20210720_143845.mp4.json', 'Dean_s list1.mp4.json', 'IMG_20210719_104717.jpg', 'IMG_20210720_132647.jpg', 'Screenshot_2021-06-16-15-03-08-968_com.google.a.jpg.json', 'IMG_20210817_190138.jpg.json', 'IMG_20210720_133226.jpg.json', 'Screenshot_2021-09-10-20-00-40-043_lockscreen.jpg', 'IMG_20210720_132647.jpg.json', 'IMG_20210720_132848.jpg', 'IMG-20210923-WA0000.jpg.json', 'IMG_20210531_213026_891.jpg', 'IMG-20210914-WA0002.jpg', 'IMG_20210720_134034.jpg', 'VID_20210808_185509.mp4', 'IMG_20210720_133149.jpg.json', 'Screenshot_2021-08-03-20-10-57-252_com.google.a.jpg.json', 'WhatsApp Video 2021-07-21 at 11.37.24 AM.mp4', 'IMG_20210607_145039.jpg.json', 'IMG_20210720_104108.jpg', 'IMG-20210811-WA0000.jpg', 'VID_20210720_150258.mp4.json', 'IMG_20210806_200342.jpg', '20210720_185252.jpg', 'IMG_20210720_151646.jpg', 'Screenshot_2021-08-07-15-23-21-878_com.google.a.jpg.json', 'IMG-20210914-WA0003.jpg', 'VID-20210721-WA0002.mp4', 'VID-20210812-WA0003.mp4', 'VID_20210720_133656.mp4.json', 'I
# Total files:  1609
# Total metadata files:  802
# Total media files:  794

# %%
missing = []

for file in all_files:
    if file not in all_media and file not in all_metadata:
        missing.append(file)
print("Check for any missed extension except metadat.json")
print(missing)

# output should only contain metadata.json
# Out:
# Check for any missed extension except metadat.json
# ['IMG_20210528_000037_294.png', 'MicrosoftTeams-image.png', 'metadata.json', 'Screenshot_2021-05-23-12-06-12-534_com.whatsapp.png', 'MicrosoftTeams-image (2).png', '20210720_174157.MP4', '20210720_174154.MP4', 'Screenshot_2021-05-23-11-31-47-389_com.whatsapp.png', 'MicrosoftTeams-image (1).png', 'Screenshot_2021-08-11-18-17-34-242_com.whatsapp.png', '20210330_015735.MP4', '20210720_185252.MP4', 'image.png']

# %%
missing_media = []
for media in all_media:
    if media + ".json" not in all_metadata:
        missing_media.append(media)

print()
print(len(missing_media))
print("media which do not have metadata file or metadata file is not named correctly: \n", missing_media)
# Out:
# 10
# media which do not have metadata file or metadata file is not named correctly:
#  ['IMG_20210720_134036(1).jpg', 'IMG_20210720_143203(1).jpg', 'IMG_20210720_132443(1).jpg', 'IMG_20210720_132300(1).jpg', 'IMG_20210720_132936(1).jpg', 'IMG_20210720_132441(1).jpg', 'IMG_20210720_132514(1).jpg', 'IMG_20210720_134048(1).jpg', 'IMG_20210720_132357(1).jpg', 'IMG_20210720_143216(1).jpg']

# %%
missing_metadata = []
for metadata in all_metadata:
    if Path(metadata).stem not in all_media:
        missing_metadata.append(metadata)

print(len(missing_metadata))
print("Json files which are not used: \n", missing_metadata)
# Out:
# 18
# Json files which are not used:
#  ['IMG_20210528_000037_294.png.json', 'MicrosoftTeams-image.png.json', 'IMG_20210720_143203.jpg(1).json', 'IMG_20210720_134036.jpg(1).json', 'image.png.json', 'IMG_20210720_132443.jpg(1).json', 'IMG_20210720_143216.jpg(1).json', 'MicrosoftTeams-image (1).png.json', 'IMG_20210720_132936.jpg(1).json', 'Screenshot_2021-05-23-12-06-12-534_com.whatsap.json', 'MicrosoftTeams-image (2).png.json', 'Screenshot_2021-05-23-11-31-47-389_com.whatsap.json', 'IMG_20210720_132357.jpg(1).json', 'Screenshot_2021-08-11-18-17-34-242_com.whatsap.json', 'IMG_20210720_132300.jpg(1).json', 'IMG_20210720_132514.jpg(1).json', 'IMG_20210720_134048.jpg(1).json', 'IMG_20210720_132441.jpg(1).json']

# %% [markdown]
# ## detect images name >46 chars, rename json files

# %%
# write a code to detect image names which have name longer than 46 characters (excluding extension .mp3, .jpeg) and rename their json files

for media in all_media:
    if len(media) > 46:
        extension = media.split(".")[-1]
        try:
            os.rename(folder_path + media[:46] + ".json", folder_path + media + ".json")
        except FileNotFoundError:
            pass

# %% [markdown]
# ### Updating lists

# %%
folder_path = '/Users/rahul.madan/Downloads/Takeout/Google Photos/Nov 2021/'
total = glob.glob(folder_path + '*')
json = glob.glob(folder_path + '*.json')
mp3 = glob.glob(folder_path + '*.mp4')
jpg = glob.glob(folder_path + '*.jpg')
JPG = glob.glob(folder_path + '*.JPG')
jpeg = glob.glob(folder_path + '*.jpeg')
HEIC = glob.glob(folder_path + '*.HEIC')
mov = glob.glob(folder_path + '*.mov')

all_files = []
all_media = []
all_metadata = []

all_media.extend([video[len(folder_path):] for video in mp3])
all_media.extend([image[len(folder_path):] for image in jpg])
all_media.extend([image[len(folder_path):] for image in JPG])
all_media.extend([image[len(folder_path):] for image in jpeg])
all_media.extend([image[len(folder_path):] for image in HEIC])
all_media.extend([image[len(folder_path):] for image in mov])

all_metadata.extend([metadata[len(folder_path):] for metadata in json])
all_metadata.remove("metadata.json")

all_files.extend([files[len(folder_path):] for files in total])
missing_media = []

for media in all_media:
    if media + ".json" not in all_metadata:
        missing_media.append(media)

print()
print(len(missing_media))
print("media which do not have metadata file or metadata file is not named correctly: \n", missing_media)

missing_metadata = []
for metadata in all_metadata:
    if Path(metadata).stem not in all_media:
        missing_metadata.append(metadata)

print(len(missing_metadata))
print("Json files which are not used: \n", missing_metadata)
# Out:
# 0
# media which do not have metadata file or metadata file is not named correctly:
#  []
# 0
# Json files which are not used:
#  []

# %% [markdown]
# ## make duplicate jsons of edited images

# %%
# write a code to make duplicate .json file if 'edited' present in media file name

for media in missing_media:
    if Path(media).stem.endswith("-edited"):
        extension = media.split(".")[-1]
        shutil.copy(folder_path+Path(media).stem[:len(Path(media).stem)-7]+"."+extension+".json",folder_path+media+".json")

# %% [markdown]
# ### Updating lists

# %%
folder_path = '/Users/rahul.madan/Downloads/Takeout/Google Photos/Nov 2021/'
total = glob.glob(folder_path + '*')
json = glob.glob(folder_path + '*.json')
mp3 = glob.glob(folder_path + '*.mp4')
jpg = glob.glob(folder_path + '*.jpg')
JPG = glob.glob(folder_path + '*.JPG')
jpeg = glob.glob(folder_path + '*.jpeg')
HEIC = glob.glob(folder_path + '*.HEIC')
mov = glob.glob(folder_path + '*.mov')

all_files = []
all_media = []
all_metadata = []

all_media.extend([video[len(folder_path):] for video in mp3])
all_media.extend([image[len(folder_path):] for image in jpg])
all_media.extend([image[len(folder_path):] for image in JPG])
all_media.extend([image[len(folder_path):] for image in jpeg])
all_media.extend([image[len(folder_path):] for image in HEIC])
all_media.extend([image[len(folder_path):] for image in mov])

all_metadata.extend([metadata[len(folder_path):] for metadata in json])
all_metadata.remove("metadata.json")

all_files.extend([files[len(folder_path):] for files in total])
missing_media = []

for media in all_media:
    if media + ".json" not in all_metadata:
        missing_media.append(media)

print()
print(len(missing_media))
print("media which do not have metadata file or metadata file is not named correctly: \n", missing_media)

missing_metadata = []
for metadata in all_metadata:
    if Path(metadata).stem not in all_media:
        missing_metadata.append(metadata)

print(len(missing_metadata))
print("Json files which are not used: \n", missing_metadata)
# Out:
# 0
# media which do not have metadata file or metadata file is not named correctly:
#  []
# 0
# Json files which are not used:
#  []

# %% [markdown]
# ## Rename json files which have (1) in them

# %%
# write a code to rename json files which have '(1)' in .json file name

metadata_mapping = {}
for file in missing_metadata:
    if "(1)" in file:
        name, ext = os.path.splitext(file)
        name = name.rstrip(')').rstrip('(1')
        main_name, main_ext = os.path.splitext(name)
        corrected_file = f"{main_name}(1){main_ext}{ext}"
        metadata_mapping[file] = corrected_file

print(metadata_mapping)

for old_metadata, new_metadata in metadata_mapping.items():
    os.rename(folder_path+old_metadata,folder_path+new_metadata)
# Out:
# {}

# %% [markdown]
# ### Updating lists

# %%
folder_path = '/Users/rahul.madan/Downloads/Takeout/Google Photos/Nov 2021/'
total = glob.glob(folder_path + '*')
json = glob.glob(folder_path + '*.json')
mp3 = glob.glob(folder_path + '*.mp4')
jpg = glob.glob(folder_path + '*.jpg')
JPG = glob.glob(folder_path + '*.JPG')
jpeg = glob.glob(folder_path + '*.jpeg')
HEIC = glob.glob(folder_path + '*.HEIC')
mov = glob.glob(folder_path + '*.mov')

all_files = []
all_media = []
all_metadata = []

all_media.extend([video[len(folder_path):] for video in mp3])
all_media.extend([image[len(folder_path):] for image in jpg])
all_media.extend([image[len(folder_path):] for image in JPG])
all_media.extend([image[len(folder_path):] for image in jpeg])
all_media.extend([image[len(folder_path):] for image in HEIC])
all_media.extend([image[len(folder_path):] for image in mov])

all_metadata.extend([metadata[len(folder_path):] for metadata in json])
all_metadata.remove("metadata.json")

all_files.extend([files[len(folder_path):] for files in total])
missing_media = []

for media in all_media:
    if media + ".json" not in all_metadata:
        missing_media.append(media)

print()
print(len(missing_media))
print("media which do not have metadata file or metadata file is not named correctly: \n", missing_media)

missing_metadata = []
for metadata in all_metadata:
    if Path(metadata).stem not in all_media:
        missing_metadata.append(metadata)

print(len(missing_metadata))
print("Json files which are not used: \n", missing_metadata)
# Out:
# 0
# media which do not have metadata file or metadata file is not named correctly:
#  []
# 0
# Json files which are not used:
#  []

# %% [markdown]
# ## OUTPUT ABOVE SHOULD BE 0 AND 0

# %% [markdown]
# # Rename images based on timestamp, location, persons

# %%
import os
import glob
from datetime import datetime, timedelta
import json


folder_path = '/Users/rahul.madan/Downloads/Takeout 2/Google Photos/May21-Sep21/'
json_files = glob.glob(os.path.join(folder_path, '*.json'))
json_files.remove(folder_path+"metadata.json")
file_names=[]
counter = 0
for file_path in json_files:
    with open(file_path, 'r+') as f:
        data = json.load(f)
        # print(data)
        counter += 1
        # print(file_path)
        extension = data["title"].split(".")[-1]
        print(extension)
        utc_datetime = datetime.utcfromtimestamp(int(data['photoTakenTime']['timestamp']))
        ist_offset = timedelta(hours=5, minutes=30)
        ist_datetime = utc_datetime + ist_offset
        file_names.append(str(ist_datetime.isoformat()+"_"+str(counter)+"."+extension))
        # print(ist_datetime.isoformat())
        # Add new key value pair to data
        data['AWS_title'] = str(ist_datetime.isoformat()+"_"+str(counter)+"."+extension)
        # Move the file pointer to the beginning of the file
        f.seek(0)
        # Write the updated data back to the file
        json.dump(data, f)
        # Truncate any remaining data in the file
        f.truncate()

print("last: ", counter)
print("Added AWS title")
# Out:
# jpg
# jpg
# jpg
# mp4
# jpg
# png
# jpg
# jpg
# jpg
# jpg
# jpeg
# jpg
# mp4
# mp4
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# mp4
# jpg
# mp4
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# mp4
# jpg
# jpg
# jpg
# jpg
# jpg
# jpeg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
# jpg
